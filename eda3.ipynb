# %% [markdown]
# <a href="https://colab.research.google.com/github/GitTanish/DataAnalysis/blob/main/eda3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as pyplot
import seaborn as sns
# %matplotlib inline

# %%
# BlackFriday dataset is used

# %% [markdown]
# ###Problem Statement
# A retail company "ABC Private Limited" wants to understand the customer purchase behaviour (specifically, purchase amount)against various products of different categories. They have shared purchase summary of various customers for selected high volume products from last month. The data set also contains customer demographics (age, gender, marital status, city_type, stay_in_current_city), product details(product_id and product category)and Total_purchase_amount from last month.
#
# Now, they want to build a model to predict the purchase amount of customer against various products which will help them to create personalised offer for customers against different products.

# %%
dft=pd.read_csv("train.csv")

# %%
dft.shape
# Out:
# (203282, 12)

# %%
dft.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
# When any kind of test and train data is given, first of all combine them

# %%
dfe = pd.read_csv('test.csv')
dfe.shape
# Out:
# (233599, 11)

# %%
# Merge both train and test
# Now, what to use Merge, concat or append?
# first of all append is deprecated lol
# Merge uses a key or id to join, while concat stacks one on the other

# %%
df=pd.concat([dft,dfe])

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
## Basic
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 436881 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     436881 non-null  int64
#  1   Product_ID                  436881 non-null  object
#  2   Gender                      436881 non-null  object
#  3   Age                         436881 non-null  object
#  4   Occupation                  436881 non-null  int64
#  5   City_Category               436881 non-null  object
#  6   Stay_In_Current_City_Years  436881 non-null  object
#  7   Marital_Status              436880 non-null  float64
#  8   Product_Category_1          436880 non-null  float64
#  9   Product_Category_2          301492 non-null  float64
#  10  Product_Category_3          133294 non-null  float64
#  11  Purchase                    203281 non-null  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 43.3+ MB

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  4.368810e+05  436881.000000   436880.000000       436880.000000
# mean   1.002982e+06       8.080345        0.410030            5.283849
# std    1.742149e+03       6.527957        0.491839            3.740045
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001433e+06       2.000000        0.000000            1.000000
# 50%    1.003017e+06       7.000000        0.000000            5.000000
# 75%    1.004448e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       301492.000000       133294.000000  203281.000000
# mean             9.848915           12.660157    9318.367609
# std              5.089742            4.124895    4976.290885
# min              2.000000            3.000000     185.000000
# 25%              5.000000            9.000000    5857.000000
# 50%              9.000000           14.000000    8059.000000
# 75%             15.000000           16.000000   12064.000000
# max             18.000000           18.000000   23961.000000

# %%
# since user id not needed for this particular problem statement
df.drop(['User_ID'],axis=1,inplace=True) # axis 0-> HOrizontal 1-> Vertical

# %%
# age is of Categorical value. So we'll convert categorical to numerical

# %%
pd.get_dummies(df['Gender'], drop_first=1)
# wow get_dummies
# Takes a categorical column (or columns) with discrete values (like "red", "blue", "green")
# Creates new columns for each unique category
# Marks each row with 1 in the column that matches the category and 0 elsewhere
# Out:
#             1
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# ...       ...
# 233594  False
# 233595  False
# 233596  False
# 233597  False
# 233598  False
#
# [436881 rows x 1 columns]

# %%
# get_dummies can be used but with this the process will be a little lengthy
# so we'll use an alternative, actually both can be used

# %%
#What it does: Maps each category to a single value you define.
#Output: One column with transformed values.

df['Gender']=df['Gender'].map({'F':0,'M':1})

# %% [markdown]
# | Scenario                         | Use `.map()`             | Use `pd.get_dummies()`            |
# | -------------------------------- | ------------------------ | --------------------------------- |
# | Simple mapping to numeric labels | ✔️                       | ❌                                 |
# | One-hot encoding for ML models   | ❌                        | ✔️                                |
# | Handling many categories easily  | ❌ (need manual mapping)  | ✔️ (automatic)                    |
# | Implies order or not?            | Yes (if numbers ordered) | No (all binary, no order implied) |

# %%
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042     NaN  0-17          10             A
# 1  P00248942     NaN  0-17          10             A
# 2  P00087842     NaN  0-17          10             A
# 3  P00085442     NaN  0-17          10             A
# 4  P00285442     NaN   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
# For this case either get_dummies() or .map({}) can be used
# df['Gender']=pd.get_dummies(df['Gender'], drop_first=1) or
# df['Gender']=df['Gender'].map({'F':0,'M':1})

# %%
# SO for this we handeled categorical feature Gender

# %%
# Handle categorical feature age
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
# pd.get_dummies(df['Age'], drop_first=True)
# Target Guiding or Tagret ordinal encoding
df['Age']=df['Age'].map({'0-17':1, '18-25':2, '26-35':3, '36-45':4, '46-50':5, '51-55':6, '55+':7})

# pd.get_dummies wasn't making sense since, these are range values and dummies provided one-head encoding

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042     NaN  NaN          10             A
# 1  P00248942     NaN  NaN          10             A
# 2  P00087842     NaN  NaN          10             A
# 3  P00085442     NaN  NaN          10             A
# 4  P00285442     NaN  NaN          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0
